# %% [markdown]
# ## Merge, Join, and Concatenate Functions in Pandas
#
# ![image.png](attachment:image.png)
#
# *Examples from Alex the Analyst on youtube.*
#
# You can find the datasets used for this [HERE](https://github.com/AlexTheAnalyst/PandasYouTubeSeries/blob/main/LOTR.csv) and [HERE](https://github.com/AlexTheAnalyst/PandasYouTubeSeries/blob/main/LOTR%202.csv)
#
# Merge Functions
#
# *

# %%
# Import libraries

Import Pandas as pd
